# %%
import torch

# %%
torch.load('../datasets/core/NASE-finetuned/1913647.pt', weights_only=True)
# Out:
# /root/anaconda3/envs/dinov2/lib/python3.9/site-packages/torch/_utils.py:776: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# {'bag_feats': tensor([[-1.7465, -0.5761,  1.9849,  ...,  2.1329,  0.8791,  0.3220],
#          [-2.3229,  1.9092, -0.0755,  ..., -1.0046,  0.1587, -0.2089],
#          [-1.9703,  0.4096,  1.9261,  ..., -1.4466, -1.0954,  1.0824],
#          ...,
#          [-2.6204,  0.0879,  0.3160,  ..., -0.5021, -0.2014,  4.2090],
#          [-0.4575,  1.7308,  2.3612,  ..., -0.4254, -0.5650,  1.8289],
#          [-1.3320,  1.6831, -0.6981,  ..., -0.1025,  1.8700,  1.1712]]),
#  'coords': ['323_75',
#   '269_44',
#   '315_133',
#   '271_137',
#   '320_42',
#   '323_77',
#   '266_129',
# ...

# %%
model_weight['teacher'].keys()
# Out:
# odict_keys(['backbone.cls_token', 'backbone.pos_embed', 'backbone.mask_token', 'backbone.patch_embed.proj.weight', 'backbone.patch_embed.proj.bias', 'backbone.blocks.0.0.norm1.weight', 'backbone.blocks.0.0.norm1.bias', 'backbone.blocks.0.0.attn.qkv.weight', 'backbone.blocks.0.0.attn.qkv.bias', 'backbone.blocks.0.0.attn.proj.weight', 'backbone.blocks.0.0.attn.proj.bias', 'backbone.blocks.0.0.ls1.gamma', 'backbone.blocks.0.0.norm2.weight', 'backbone.blocks.0.0.norm2.bias', 'backbone.blocks.0.0.mlp.w12.weight', 'backbone.blocks.0.0.mlp.w12.bias', 'backbone.blocks.0.0.mlp.w3.weight', 'backbone.blocks.0.0.mlp.w3.bias', 'backbone.blocks.0.0.ls2.gamma', 'backbone.blocks.0.1.norm1.weight', 'backbone.blocks.0.1.norm1.bias', 'backbone.blocks.0.1.attn.qkv.weight', 'backbone.blocks.0.1.attn.qkv.bias', 'backbone.blocks.0.1.attn.proj.weight', 'backbone.blocks.0.1.attn.proj.bias', 'backbone.blocks.0.1.ls1.gamma', 'backbone.blocks.0.1.norm2.weight', 'backbone.blocks.0.1.norm2.bias', 'backbone.blocks
# ...
